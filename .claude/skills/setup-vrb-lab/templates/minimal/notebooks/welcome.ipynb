# %% [markdown]
# # __LAB_TITLE__
#
# Welcome to this Virtual Research Lab. Run the cells below to check that the environment works.
#
# - The **Desktop** (VNC) is available through the launcher or `Help` if a graphical application needs a screen.
# - A terminal is available via `File > New > Terminal`.

# %%
import sys, os, platform
print('Python', sys.version.split()[0], 'on', platform.platform())
print('ROS_DISTRO =', os.environ.get('ROS_DISTRO', 'not set'))
print('Repository:', os.environ.get('REPO_DIR', os.getcwd()))

# %% [markdown]
# ## __PROJECT_NAME__
#
# Replace this cell with a short introduction and the first steps of the project.

# %%
# Example: import the integrated project
# import __PROJECT_NAME__
